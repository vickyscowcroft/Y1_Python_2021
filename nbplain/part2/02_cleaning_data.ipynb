# %% [markdown]
# # Cleaning data with `pandas`

# %% [markdown]
# **Questions**
# - How can we deal with imperfect data?
# - What is tidy data?
#
# **Objectives**
# - Clean a dataset using `pandas`

# %% [markdown]
# In the previous section we learned how to read data in with `pandas` and how to access the data within a dataframe. Here we will be looking at how to "clean" our data while still staying within the bounds of reproducible science.

# %% [markdown]
# # Exercise: Read in the data
# If you haven't already, import `pandas` and read the exoplanet data into a dataframe. I'm calling the dataframe `exo_df`, the same as in the last section. If you're reading in the data for the first time now rename the first column to `name` rather than `# name`. You can check the [previous section](01_intro_pandas.ipynb) if you need a refresher on how to do this. Check that the data has been read correctly by looking at your dataframe.

# %%
import pandas as pd

# %%
exo_df = pd.read_csv("../data/Exoplanet_catalog_2019.csv")

# %%
exo_df.rename(columns={'# name':'name'}, inplace=True)

# %%
exo_df
# Out:
#                 name  orbital_period  semi_major_axis  eccentricity  \
# 0           11 Com b      326.030000         1.290000       0.23100
# 1           11 UMi b      516.220000         1.540000       0.08000
# 2           14 And b      185.840000         0.830000       0.00000
# 3           14 Her b     1773.400000         2.770000       0.36900
# 4         16 Cyg B b      799.500000         1.680000       0.68900
# 5           18 Del b      993.300000         2.600000       0.08000
# 6     1SWASP J1407 b     3725.000000         3.900000           NaN
# 7           24 Boo b       30.350600         0.190000       0.04200
# 8           24 Sex b      452.800000         1.333000       0.09000
# 9           24 Sex c      883.000000         2.080000       0.29000
# 10        30 Ari B b      335.100000         0.995000       0.28900
# 11          38 Vir b      825.900000         1.820000       0.03000
# 12           4 Uma b      269.300000         0.870000       0.43200
# 13          42 Dra b      479.100000         1.190000       0.38000
# 14          47 Uma b     1078.000000         2.100000       0.03200
# 15          47 Uma c     2391.000000         3.600000       0.09800
# 16          47 Uma d    14002.000000        11.600000       0.16000
# 17          51 Peg b        4.230800         0.052000       0.00690
# 18          55 Cnc b       14.653140         0.113390       0.00230
# 19          55 Cnc c       44.373000         0.237350       0.07200
# 20          55 Cnc d     4867.000000         5.446000       0.02690
# 21          55 Cnc e        0.736548         0.015439       0.02800
# 22          55 Cnc f      260.910000         0.773300       0.08000
# 23           6 Lyn b      899.000000         2.200000       0.13400
# 24          61 Vir b        4.215000         0.050201       0.12000
# 25          61 Vir c       38.021000         0.217500       0.14000
# 26          61 Vir d      123.010000         0.476000       0.35000
# 27           7 CMA c      988.900000         2.143000       0.04600
# 28           7 CMa b      736.900000         1.761000       0.05500
# 29          70 Vir b      116.670000         0.480000       0.43000
# ...              ...             ...              ...           ...
# 3802   gamma 1 Leo b      428.500000         1.190000       0.14400
# 3803  gamma Cephei b      903.300000         2.050000       0.04900
# 3804     gamma Lib b      415.200000         1.239700       0.25000
# 3805     gamma Lib c      964.600000         2.176100       0.05400
# 3806     kappa CrB b     1251.000000         2.600000       0.19000
# 3807     kepler-80 g       14.645580         0.140000           NaN
# 3808       ksi Aql b      136.750000         0.580000       0.00000
# 3809        mu Ara b      643.250000         1.500000       0.12800
# 3810        mu Ara c        9.638600         0.090940       0.17200
# 3811        mu Ara d      310.550000         0.921000       0.06660
# 3812        mu Ara e     4205.800000         5.235000       0.09850
# 3813        mu Leo b      357.800000         1.100000       0.09000
# 3814        nu Oph b      530.210000         1.790000       0.12400
# 3815        nu Oph c     3184.830000         5.931000       0.18000
# 3816       ome Ser b      277.020000         1.100000       0.10600
# 3817       omi CrB b      187.300000         0.830000       0.19100
# 3818       omi UMa b     1630.000000         3.900000           NaN
# 3819        pi Men b     2091.200000         3.220000       0.63900
# 3820        pi Men c        6.268340         0.067020           NaN
# 3821       sig Per b      579.800000         1.800000       0.30000
# 3822       tau Boo b        3.312490         0.046000       0.07870
# 3823       tau Cet e      162.870000         0.538000       0.18000
# 3824       tau Cet f      636.130000         1.334000       0.16000
# 3825       tau Cet g       20.000000         0.133000       0.06000
# 3826       tau Cet h       49.410000         0.243000       0.23000
# 3827       tau Gem b      305.500000         1.170000       0.03100
# 3828       ups And b        4.617110         0.059000       0.01186
# 3829       ups And c      240.937000         0.861000       0.24450
# 3830       ups And d     1281.439000         2.550000       0.31600
# 3831       ups And e     3848.860000         5.245600       0.00536
#
#       discovered   detection_type     star_name  star_distance  \
# 0         2008.0  Radial Velocity        11 Com       110.6000
# 1         2009.0  Radial Velocity        11 UMi       119.5000
# 2         2008.0  Radial Velocity        14 And        76.4000
# 3         2002.0  Radial Velocity        14 Her        18.1000
# 4         1996.0  Radial Velocity      16 Cyg B        21.4100
# 5         2008.0  Radial Velocity        18 Del        73.1000
# 6         2012.0  Primary Transit  1SWASP J1407       133.0000
# 7         2018.0  Radial Velocity        24 Boo       100.0000
# 8         2010.0  Radial Velocity        24 Sex        72.2084
# 9         2010.0  Radial Velocity        24 Sex        72.2084
# 10        2009.0  Radial Velocity      30 Ari B        39.4000
# 11        2016.0  Primary Transit        38 Vir            NaN
# 12        2007.0  Radial Velocity         4 Uma        78.5000
# 13        2009.0  Radial Velocity        42 Dra        97.3000
# 14        1996.0  Radial Velocity        47 Uma        13.9700
# 15        2001.0  Radial Velocity        47 Uma        13.9700
# 16        2010.0  Radial Velocity        47 Uma        13.9700
# 17        1995.0  Radial Velocity        51 Peg        14.7000
# 18        1996.0  Radial Velocity        55 Cnc        12.3400
# 19        2002.0  Radial Velocity        55 Cnc        12.3400
# 20        2002.0  Radial Velocity        55 Cnc        12.3400
# 21        2004.0  Primary Transit        55 Cnc        12.3400
# 22        2007.0  Radial Velocity        55 Cnc        12.3400
# 23        2008.0  Radial Velocity         6 Lyn        56.9000
# 24        2009.0  Radial Velocity        61 Vir         8.5200
# 25        2009.0  Radial Velocity        61 Vir         8.5200
# 26        2009.0  Radial Velocity        61 Vir         8.5200
# 27        2019.0  Radial Velocity         7 CMa        19.7500
# 28        2011.0  Radial Velocity         7 CMa        19.7500
# 29        1996.0  Radial Velocity        70 Vir        22.0000
# ...          ...              ...           ...            ...
# 3802      2009.0  Radial Velocity   gamma 1 Leo        38.5000
# 3803      2003.0  Radial Velocity  gamma Cephei        13.7900
# 3804      2018.0  Radial Velocity     gamma Lib        50.2000
# 3805      2018.0  Radial Velocity     gamma Lib        50.2000
# 3806      2007.0  Radial Velocity     kappa CrB        31.1000
# 3807      2017.0  Primary Transit     Kepler-80            NaN
# 3808      2008.0  Radial Velocity       ksi Aql        62.7000
# 3809      2000.0  Radial Velocity        mu Ara        15.3000
# 3810      2004.0  Radial Velocity        mu Ara        15.3000
# 3811      2004.0  Radial Velocity        mu Ara        15.3000
# 3812      2006.0  Radial Velocity        mu Ara        15.3000
# 3813      2014.0  Radial Velocity        mu Leo        38.0500
# 3814      2004.0  Radial Velocity        nu Oph        46.8000
# 3815      2010.0  Radial Velocity        nu Oph        46.8000
# 3816      2013.0  Radial Velocity       ome Ser        80.6000
# 3817      2012.0  Radial Velocity      omi  CrB        84.0000
# 3818      2012.0  Radial Velocity       omi UMa        56.3000
# 3819      2001.0  Radial Velocity        pi Men        18.3700
# 3820      2018.0  Primary Transit        pi Men        18.3700
# 3821      2014.0  Radial Velocity       sig Per       108.3000
# 3822      1996.0  Radial Velocity       tau Boo        15.6000
# 3823      2012.0  Radial Velocity       tau Cet         3.6500
# 3824      2012.0  Radial Velocity       tau Cet         3.6500
# 3825      2017.0  Radial Velocity       tau Cet         3.6500
# 3826      2017.0  Radial Velocity       tau Cet         3.6500
# 3827      2004.0  Radial Velocity       tau Gem        98.4000
# 3828      1996.0  Radial Velocity       ups And        13.4700
# 3829      1999.0  Radial Velocity       ups And        13.4700
# 3830      1999.0  Radial Velocity       ups And        13.4700
# 3831      2010.0  Radial Velocity       ups And        13.4700
#
#       star_metallicity  star_mass star_sp_type
# 0               -0.350      2.700       G8 III
# 1                0.040      1.800        K4III
# 2               -0.240      2.200        K0III
# 3                0.430      0.900         K0 V
# 4                0.080      1.010       G2.5 V
# 5               -0.052      2.300        G6III
# 6                  NaN      0.900          NaN
# 7               -0.770      0.990         G3IV
# 8               -0.030      1.540           G5
# 9               -0.030      1.540           G5
# 10               0.120      1.220          F6V
# 11               0.070      1.180         F6 V
# 12              -0.250      1.234        K1III
# 13              -0.460      0.980      K1.5III
# 14               0.000      1.030          G0V
# 15               0.000      1.030          G0V
# 16               0.000      1.030          G0V
# 17               0.200      1.110        G2 IV
# 18               0.310      1.015       K0IV-V
# 19               0.310      1.015       K0IV-V
# 20               0.310      1.015       K0IV-V
# 21               0.310      1.015       K0IV-V
# 22               0.310      1.015       K0IV-V
# 23              -0.130      1.700         K0IV
# 24              -0.010      0.950          G5V
# 25              -0.010      0.950          G5V
# 26              -0.010      0.950          G5V
# 27               0.210      1.520       K1 III
# 28               0.210      1.520       K1 III
# 29              -0.110      0.920         G4 V
# ...                ...        ...          ...
# 3802            -0.510      1.230        K0III
# 3803             0.180      1.400     K1III-IV
# 3804            -0.300      1.470        K0III
# 3805            -0.300      1.470        K0III
# 3806             0.140      1.510        K1IVa
# 3807            -0.560        NaN          NaN
# 3808            -0.205      2.200       G9IIIb
# 3809             0.280      1.080      G3 IV-V
# 3810             0.280      1.080      G3 IV-V
# 3811             0.280      1.080      G3 IV-V
# 3812             0.280      1.080      G3 IV-V
# 3813             0.300      1.500        K2III
# 3814             0.130      3.040        K0III
# 3815             0.130      3.040        K0III
# 3816            -0.240      2.170       G8 III
# 3817            -0.290      2.130        K0III
# 3818            -0.090      3.090     G4II-III
# 3819             0.080      1.094          G0V
# 3820             0.080      1.094          G0V
# 3821            -0.220      2.250        K3III
# 3822             0.280      1.300         F7 V
# 3823            -0.550      0.783       G8.5 V
# 3824            -0.550      0.783       G8.5 V
# 3825            -0.550      0.783       G8.5 V
# 3826            -0.550      0.783       G8.5 V
# 3827             0.140      2.300        K2III
# 3828             0.090      1.270         F8 V
# 3829             0.090      1.270         F8 V
# 3830             0.090      1.270         F8 V
# 3831             0.090      1.270         F8 V
#
# [3832 rows x 11 columns]

# %% [markdown]
# As you may remember from your Semester 1 coursework, there are some gaps in the original csv file. Not every object has data available for every variable. This is a hassle when we're using something like `np.loadtxt` to read in the data, but `pandas` can handle missing variables using the **`NaN`** value.
#
# `NaN` stands for 'Not a Number' and is the value that `pandas` fills your empty cells with.

# %% [markdown]
# # Information: NaN, null, NA...
#
# `NaN` is probably the most common way to show missing data, but you might also come across `NA` or `null`. If you're using some data where the missing values are represented by something else (for example, `99.999` or `----` you can use the `na_values` argument in `pd.read_csv` to tell it what corresponds to missing data.

# %% [markdown]
# We can select all the rows in a dataframe that contain a `NaN` value using the `isna()` function. This is another logical operation; we're selecting the rows that have a `NaN` value. Because we want to select all the rows with a `NaN` and don't care which column it's in, we use `.any(axis=1)`, where `axis=1` says to do the operation on each row.

# %%
exo_df[exo_df.isna().any(axis=1)]
# Out:
#                    name  orbital_period  semi_major_axis  eccentricity  \
# 6        1SWASP J1407 b     3725.000000          3.90000           NaN
# 11             38 Vir b      825.900000          1.82000         0.030
# 30             75 Cet b      691.900000          2.10000           NaN
# 34            AD 3116 b        1.982796              NaN         0.146
# 35             AD Leo b        2.225990          0.02500         0.030
# 37         BD+03 2562 b      481.900000          1.30000         0.200
# 39         BD+15 2375 b      153.220000          0.57600         0.001
# 43          BD+20 274 c      578.200000          1.30000           NaN
# 47          BD+48 738 b      392.600000          1.00000         0.200
# 48          BD+49 828 b     2590.000000          4.20000         0.350
# 57         Barnard's  b      232.800000              NaN         0.320
# 58             CI Tau b        8.989100              NaN         0.250
# 59           CVSO 30 b         0.448413          0.00838           NaN
# 60           Cha Ha 8 b     1895.000000          1.02000         0.590
# 67           CoRoT-15 b        3.060360          0.04500         0.000
# 74           CoRoT-21 b        2.724740          0.04170         0.000
# 79           CoRoT-25 b        4.860690          0.05780           NaN
# 81           CoRoT-27 b        3.575320          0.04760         0.065
# 87           CoRoT-32 b        6.718370          0.07100           NaN
# 88           CoRoT-33 b        5.819143          0.05790         0.070
# 89            CoRoT-4 b        9.202050          0.09000         0.000
# 91            CoRoT-6 b        8.886593          0.08550         0.100
# 97           DS Tuc A b        8.138268          0.07950           NaN
# 98             DW Lyn b             NaN          1.14800           NaN
# 99             DW Uma b     4967.000000          5.80000           NaN
# 100   EPIC  211945201 b       19.492130          0.14800         0.000
# 101    EPIC 201128338 b       32.652700          0.17350           NaN
# 102    EPIC 201295312 b        5.656390              NaN         0.120
# 103    EPIC 201598502 b        7.515540          0.60100           NaN
# 104    EPIC 203826436 b        4.441170              NaN           NaN
# ...                 ...             ...              ...           ...
# 3738          WASP-73 b        4.087220          0.05512         0.000
# 3742        WASP-77 A b        1.360031          0.02400           NaN
# 3752        WASP-85 A b        2.655678          0.03900           NaN
# 3754          WASP-88 b        4.954000          0.06431         0.000
# 3755          WASP-89 b        3.356423          0.04270         0.193
# 3757          WASP-91 b        2.798581          0.03700         0.000
# 3759          WASP-93 b        2.732532          0.04211           NaN
# 3760        WASP-94 A b        3.950191          0.05500         0.000
# 3761        WASP-94 B b        2.008390          0.03350           NaN
# 3762          WASP-95 b        2.184673          0.03416         0.000
# 3763          WASP-96 b        3.425260          0.04530         0.000
# 3764          WASP-97 b        2.072760          0.03303         0.000
# 3765          WASP-98 b        2.962640          0.03600         0.000
# 3766          WASP-99 b        5.752510          0.07170         0.000
# 3767      WD 0137-349 b        0.079430          0.00300           NaN
# 3768      WD 0837+185 B        0.175000          0.00600           NaN
# 3769      WD 1145+017 b        0.187500              NaN           NaN
# 3770            WTS-1 b        3.352059          0.04700         0.100
# 3775         Wolf 359 b     2938.000000          1.84500         0.040
# 3776         Wolf 359 c        2.686870          0.01800         0.150
# 3777         Wolf 503 b        6.001180          0.05710           NaN
# 3778             XO-1 b        3.941513          0.04880         0.000
# 3786          YBP1194 b        6.958000              NaN         0.240
# 3787          YBP1514 b        5.118000              NaN         0.390
# 3788           YBP401 b        4.087000              NaN         0.150
# 3794         beta Pic c     1238.000000          2.72000         0.248
# 3798        eps Ind A b    16509.000000         11.55000         0.260
# 3807        kepler-80 g       14.645580          0.14000           NaN
# 3818          omi UMa b     1630.000000          3.90000           NaN
# 3820           pi Men c        6.268340          0.06702           NaN
#
#       discovered   detection_type        star_name  star_distance  \
# 6         2012.0  Primary Transit     1SWASP J1407        133.000
# 11        2016.0  Primary Transit           38 Vir            NaN
# 30        2012.0  Radial Velocity           75 Cet         81.500
# 34        2017.0  Primary Transit          AD 3116        186.540
# 35        2019.0  Radial Velocity           AD Leo          4.966
# 37        2017.0  Radial Velocity       BD+03 2562       2618.000
# 39        2016.0  Radial Velocity       BD+15 2375        774.000
# 43        2012.0  Radial Velocity        BD+20 274            NaN
# 47        2011.0  Radial Velocity       BD +48 738            NaN
# 48        2015.0  Radial Velocity        BD+49 828            NaN
# 57        2018.0  Radial Velocity   Barnard's star          1.800
# 58        2016.0  Radial Velocity           CI Tau        158.000
# 59        2012.0  Primary Transit          CVSO 30        330.000
# 60        2007.0  Radial Velocity         Cha Ha 8        196.760
# 67        2010.0  Primary Transit         CoRoT-15            NaN
# 74        2011.0  Primary Transit         CoRoT-21            NaN
# 79        2012.0  Primary Transit         CoRoT-25       1000.000
# 81        2012.0  Primary Transit         CoRoT-27            NaN
# 87        2017.0  Primary Transit         CoRoT-32            NaN
# 88        2015.0  Primary Transit         CoRoT-33            NaN
# 89        2008.0  Primary Transit          CoRoT-4            NaN
# 91        2009.0  Primary Transit          CoRoT-6            NaN
# 97        2019.0  Primary Transit         DS Tuc A         44.120
# 98        2013.0  Radial Velocity           DW Lyn            NaN
# 99        2016.0  Radial Velocity           DW Uma            NaN
# 100       2018.0  Primary Transit  EPIC  211945201        182.600
# 101       2017.0  Primary Transit   EPIC 201128338        112.000
# 102       2016.0  Primary Transit   EPIC 201295312            NaN
# 103       2017.0  Primary Transit   EPIC 201598502        126.000
# 104       2015.0  Primary Transit   EPIC 203826436            NaN
# ...          ...              ...              ...            ...
# 3738      2013.0  Primary Transit          WASP-73            NaN
# 3742      2012.0  Primary Transit         WASP-77A            NaN
# 3752      2014.0  Primary Transit          WASP-85            NaN
# 3754      2013.0  Primary Transit          WASP-88            NaN
# 3755      2014.0  Primary Transit          WASP-89            NaN
# 3757      2017.0  Primary Transit          WASP-91            NaN
# 3759      2016.0  Primary Transit          WASP-93        250.000
# 3760      2014.0  Primary Transit        WASP-94 A            NaN
# 3761      2014.0  Radial Velocity        WASP-94 B            NaN
# 3762      2013.0  Primary Transit          WASP-95            NaN
# 3763      2013.0  Primary Transit          WASP-96            NaN
# 3764      2013.0  Primary Transit          WASP-97            NaN
# 3765      2013.0  Primary Transit          WASP-98            NaN
# 3766      2013.0  Primary Transit          WASP-99            NaN
# 3767      2006.0  Radial Velocity      WD 0137-349        102.260
# 3768      2012.0  Radial Velocity      WD 0837+185            NaN
# 3769      2015.0  Primary Transit      WD 1145+017        174.000
# 3770      2012.0  Primary Transit            WTS-1       3200.000
# 3775      2019.0  Radial Velocity         Wolf 359          2.420
# 3776      2019.0  Radial Velocity         Wolf 359          2.420
# 3777      2018.0  Primary Transit         Wolf 503         44.583
# 3778      2006.0  Primary Transit             XO-1        200.000
# 3786      2014.0  Radial Velocity          YBP1194            NaN
# 3787      2014.0  Radial Velocity          YBP1514            NaN
# 3788      2016.0  Radial Velocity           YBP401        843.000
# 3794      2019.0  Radial Velocity         beta Pic         19.300
# 3798      2018.0  Radial Velocity        eps Ind A          3.620
# 3807      2017.0  Primary Transit        Kepler-80            NaN
# 3818      2012.0  Radial Velocity          omi UMa         56.300
# 3820      2018.0  Primary Transit           pi Men         18.370
#
#       star_metallicity  star_mass star_sp_type
# 6                  NaN      0.900          NaN
# 11               0.070      1.180         F6 V
# 30               0.000      2.490        G3III
# 34                 NaN      0.276         M3.9
# 35                 NaN        NaN          M4V
# 37              -0.710      1.140          NaN
# 39              -0.220      1.080          NaN
# 43              -0.460      0.800           K5
# 47              -0.200      0.740        K0III
# 48              -0.190      1.520           KO
# 57                 NaN      0.163          M4V
# 58                 NaN      0.900         K4IV
# 59                 NaN      0.390       M3 PMS
# 60                 NaN      0.085         M6.5
# 67                 NaN        NaN          F7V
# 74               0.000      1.290         F8IV
# 79              -0.010      1.090          G0V
# 81               0.100      1.050           G2
# 87               0.000      1.090         G0VI
# 88               0.440      0.860          G9V
# 89               0.050      1.100          F8V
# 91              -0.200      1.055          F9V
# 97              -0.080      0.959          G6V
# 98                 NaN        NaN        SdB D
# 99                 NaN        NaN           M3
# 100              0.100      1.180          NaN
# 101              0.090      0.654        M0.0V
# 102              0.130      1.130          NaN
# 103             -0.260      0.512         M3.0
# 104             -0.030      0.900          G3V
# ...                ...        ...          ...
# 3738             0.140      1.340           F9
# 3742             0.000      1.002          G8V
# 3752               NaN      1.090           G8
# 3754            -0.008      1.450           F6
# 3755             0.150      0.920           K3
# 3757             0.190      0.840           K3
# 3759             0.070      1.300           F4
# 3760             0.260      1.290           F8
# 3761             0.230      1.240           F9
# 3762             0.140      1.110           G2
# 3763             0.140      1.060           G8
# 3764             0.230      1.120           G5
# 3765            -0.600      0.690           G7
# 3766             0.210      1.480           F8
# 3767               NaN      0.390           WD
# 3768               NaN      0.798        WD DA
# 3769               NaN        NaN           WD
# 3770            -0.250      1.200          NaN
# 3775               NaN        NaN          M6V
# 3776               NaN        NaN          M6V
# 3777            -0.470      0.688        K3.5V
# 3778               NaN      1.000          G1V
# 3786             0.023      1.010          G5V
# 3787             0.030      0.960          G5V
# 3788               NaN      1.140          F9V
# 3794               NaN      1.730          A6V
# 3798               NaN      0.762          K2V
# 3807            -0.560        NaN          NaN
# 3818            -0.090      3.090     G4II-III
# 3820             0.080      1.094          G0V
#
# [2866 rows x 11 columns]

# %% [markdown]
# At the bottom of the output we can see the size of the dataframe that's returned - 2866 rows by 11 columns. Compare that to the original size of our dataframe... that's a lot of `NaN`s!
#
# It's handy to check which rows have missing data, but what if we're only concerned with those that aren't missing data? Then we can do the inverse to return only the rows **without** `NaN` values.
#
# We can get this in almost exactly the same command, just one character different. We change
# `exo_df.isna()` to `~exo_df.isna()`. The `~` is another way of saying `not.

# %%
exo_df[~exo_df.isna().any(axis=1)]
# Out:
#                 name  orbital_period  semi_major_axis  eccentricity  \
# 0           11 Com b      326.030000         1.290000       0.23100
# 1           11 UMi b      516.220000         1.540000       0.08000
# 2           14 And b      185.840000         0.830000       0.00000
# 3           14 Her b     1773.400000         2.770000       0.36900
# 4         16 Cyg B b      799.500000         1.680000       0.68900
# 5           18 Del b      993.300000         2.600000       0.08000
# 7           24 Boo b       30.350600         0.190000       0.04200
# 8           24 Sex b      452.800000         1.333000       0.09000
# 9           24 Sex c      883.000000         2.080000       0.29000
# 10        30 Ari B b      335.100000         0.995000       0.28900
# 12           4 Uma b      269.300000         0.870000       0.43200
# 13          42 Dra b      479.100000         1.190000       0.38000
# 14          47 Uma b     1078.000000         2.100000       0.03200
# 15          47 Uma c     2391.000000         3.600000       0.09800
# 16          47 Uma d    14002.000000        11.600000       0.16000
# 17          51 Peg b        4.230800         0.052000       0.00690
# 18          55 Cnc b       14.653140         0.113390       0.00230
# 19          55 Cnc c       44.373000         0.237350       0.07200
# 20          55 Cnc d     4867.000000         5.446000       0.02690
# 21          55 Cnc e        0.736548         0.015439       0.02800
# 22          55 Cnc f      260.910000         0.773300       0.08000
# 23           6 Lyn b      899.000000         2.200000       0.13400
# 24          61 Vir b        4.215000         0.050201       0.12000
# 25          61 Vir c       38.021000         0.217500       0.14000
# 26          61 Vir d      123.010000         0.476000       0.35000
# 27           7 CMA c      988.900000         2.143000       0.04600
# 28           7 CMa b      736.900000         1.761000       0.05500
# 29          70 Vir b      116.670000         0.480000       0.43000
# 31           8 Umi b       93.400000         0.490000       0.06000
# 32          81 Cet b      952.700000         2.500000       0.20600
# ...              ...             ...              ...           ...
# 3799       eps Tau b      594.900000         1.900000       0.15100
# 3800       eta Cet b      403.500000         1.270000       0.13000
# 3801       eta Cet c      751.900000         1.930000       0.10000
# 3802   gamma 1 Leo b      428.500000         1.190000       0.14400
# 3803  gamma Cephei b      903.300000         2.050000       0.04900
# 3804     gamma Lib b      415.200000         1.239700       0.25000
# 3805     gamma Lib c      964.600000         2.176100       0.05400
# 3806     kappa CrB b     1251.000000         2.600000       0.19000
# 3808       ksi Aql b      136.750000         0.580000       0.00000
# 3809        mu Ara b      643.250000         1.500000       0.12800
# 3810        mu Ara c        9.638600         0.090940       0.17200
# 3811        mu Ara d      310.550000         0.921000       0.06660
# 3812        mu Ara e     4205.800000         5.235000       0.09850
# 3813        mu Leo b      357.800000         1.100000       0.09000
# 3814        nu Oph b      530.210000         1.790000       0.12400
# 3815        nu Oph c     3184.830000         5.931000       0.18000
# 3816       ome Ser b      277.020000         1.100000       0.10600
# 3817       omi CrB b      187.300000         0.830000       0.19100
# 3819        pi Men b     2091.200000         3.220000       0.63900
# 3821       sig Per b      579.800000         1.800000       0.30000
# 3822       tau Boo b        3.312490         0.046000       0.07870
# 3823       tau Cet e      162.870000         0.538000       0.18000
# 3824       tau Cet f      636.130000         1.334000       0.16000
# 3825       tau Cet g       20.000000         0.133000       0.06000
# 3826       tau Cet h       49.410000         0.243000       0.23000
# 3827       tau Gem b      305.500000         1.170000       0.03100
# 3828       ups And b        4.617110         0.059000       0.01186
# 3829       ups And c      240.937000         0.861000       0.24450
# 3830       ups And d     1281.439000         2.550000       0.31600
# 3831       ups And e     3848.860000         5.245600       0.00536
#
#       discovered   detection_type     star_name  star_distance  \
# 0         2008.0  Radial Velocity        11 Com       110.6000
# 1         2009.0  Radial Velocity        11 UMi       119.5000
# 2         2008.0  Radial Velocity        14 And        76.4000
# 3         2002.0  Radial Velocity        14 Her        18.1000
# 4         1996.0  Radial Velocity      16 Cyg B        21.4100
# 5         2008.0  Radial Velocity        18 Del        73.1000
# 7         2018.0  Radial Velocity        24 Boo       100.0000
# 8         2010.0  Radial Velocity        24 Sex        72.2084
# 9         2010.0  Radial Velocity        24 Sex        72.2084
# 10        2009.0  Radial Velocity      30 Ari B        39.4000
# 12        2007.0  Radial Velocity         4 Uma        78.5000
# 13        2009.0  Radial Velocity        42 Dra        97.3000
# 14        1996.0  Radial Velocity        47 Uma        13.9700
# 15        2001.0  Radial Velocity        47 Uma        13.9700
# 16        2010.0  Radial Velocity        47 Uma        13.9700
# 17        1995.0  Radial Velocity        51 Peg        14.7000
# 18        1996.0  Radial Velocity        55 Cnc        12.3400
# 19        2002.0  Radial Velocity        55 Cnc        12.3400
# 20        2002.0  Radial Velocity        55 Cnc        12.3400
# 21        2004.0  Primary Transit        55 Cnc        12.3400
# 22        2007.0  Radial Velocity        55 Cnc        12.3400
# 23        2008.0  Radial Velocity         6 Lyn        56.9000
# 24        2009.0  Radial Velocity        61 Vir         8.5200
# 25        2009.0  Radial Velocity        61 Vir         8.5200
# 26        2009.0  Radial Velocity        61 Vir         8.5200
# 27        2019.0  Radial Velocity         7 CMa        19.7500
# 28        2011.0  Radial Velocity         7 CMa        19.7500
# 29        1996.0  Radial Velocity        70 Vir        22.0000
# 31        2015.0  Radial Velocity         8 Umi       159.1000
# 32        2008.0  Radial Velocity        81 Cet        97.2000
# ...          ...              ...           ...            ...
# 3799      2007.0  Radial Velocity       eps Tau        45.0000
# 3800      2014.0  Radial Velocity       eta Cet        38.0000
# 3801      2014.0  Radial Velocity       eta Cet        38.0000
# 3802      2009.0  Radial Velocity   gamma 1 Leo        38.5000
# 3803      2003.0  Radial Velocity  gamma Cephei        13.7900
# 3804      2018.0  Radial Velocity     gamma Lib        50.2000
# 3805      2018.0  Radial Velocity     gamma Lib        50.2000
# 3806      2007.0  Radial Velocity     kappa CrB        31.1000
# 3808      2008.0  Radial Velocity       ksi Aql        62.7000
# 3809      2000.0  Radial Velocity        mu Ara        15.3000
# 3810      2004.0  Radial Velocity        mu Ara        15.3000
# 3811      2004.0  Radial Velocity        mu Ara        15.3000
# 3812      2006.0  Radial Velocity        mu Ara        15.3000
# 3813      2014.0  Radial Velocity        mu Leo        38.0500
# 3814      2004.0  Radial Velocity        nu Oph        46.8000
# 3815      2010.0  Radial Velocity        nu Oph        46.8000
# 3816      2013.0  Radial Velocity       ome Ser        80.6000
# 3817      2012.0  Radial Velocity      omi  CrB        84.0000
# 3819      2001.0  Radial Velocity        pi Men        18.3700
# 3821      2014.0  Radial Velocity       sig Per       108.3000
# 3822      1996.0  Radial Velocity       tau Boo        15.6000
# 3823      2012.0  Radial Velocity       tau Cet         3.6500
# 3824      2012.0  Radial Velocity       tau Cet         3.6500
# 3825      2017.0  Radial Velocity       tau Cet         3.6500
# 3826      2017.0  Radial Velocity       tau Cet         3.6500
# 3827      2004.0  Radial Velocity       tau Gem        98.4000
# 3828      1996.0  Radial Velocity       ups And        13.4700
# 3829      1999.0  Radial Velocity       ups And        13.4700
# 3830      1999.0  Radial Velocity       ups And        13.4700
# 3831      2010.0  Radial Velocity       ups And        13.4700
#
#       star_metallicity  star_mass star_sp_type
# 0               -0.350      2.700       G8 III
# 1                0.040      1.800        K4III
# 2               -0.240      2.200        K0III
# 3                0.430      0.900         K0 V
# 4                0.080      1.010       G2.5 V
# 5               -0.052      2.300        G6III
# 7               -0.770      0.990         G3IV
# 8               -0.030      1.540           G5
# 9               -0.030      1.540           G5
# 10               0.120      1.220          F6V
# 12              -0.250      1.234        K1III
# 13              -0.460      0.980      K1.5III
# 14               0.000      1.030          G0V
# 15               0.000      1.030          G0V
# 16               0.000      1.030          G0V
# 17               0.200      1.110        G2 IV
# 18               0.310      1.015       K0IV-V
# 19               0.310      1.015       K0IV-V
# 20               0.310      1.015       K0IV-V
# 21               0.310      1.015       K0IV-V
# 22               0.310      1.015       K0IV-V
# 23              -0.130      1.700         K0IV
# 24              -0.010      0.950          G5V
# 25              -0.010      0.950          G5V
# 26              -0.010      0.950          G5V
# 27               0.210      1.520       K1 III
# 28               0.210      1.520       K1 III
# 29              -0.110      0.920         G4 V
# 31              -0.030      1.800           K0
# 32              -0.060      2.400        G5III
# ...                ...        ...          ...
# 3799             0.170      2.700       K0 III
# 3800             0.120      1.700        K1III
# 3801             0.120      1.700        K1III
# 3802            -0.510      1.230        K0III
# 3803             0.180      1.400     K1III-IV
# 3804            -0.300      1.470        K0III
# 3805            -0.300      1.470        K0III
# 3806             0.140      1.510        K1IVa
# 3808            -0.205      2.200       G9IIIb
# 3809             0.280      1.080      G3 IV-V
# 3810             0.280      1.080      G3 IV-V
# 3811             0.280      1.080      G3 IV-V
# 3812             0.280      1.080      G3 IV-V
# 3813             0.300      1.500        K2III
# 3814             0.130      3.040        K0III
# 3815             0.130      3.040        K0III
# 3816            -0.240      2.170       G8 III
# 3817            -0.290      2.130        K0III
# 3819             0.080      1.094          G0V
# 3821            -0.220      2.250        K3III
# 3822             0.280      1.300         F7 V
# 3823            -0.550      0.783       G8.5 V
# 3824            -0.550      0.783       G8.5 V
# 3825            -0.550      0.783       G8.5 V
# 3826            -0.550      0.783       G8.5 V
# 3827             0.140      2.300        K2III
# 3828             0.090      1.270         F8 V
# 3829             0.090      1.270         F8 V
# 3830             0.090      1.270         F8 V
# 3831             0.090      1.270         F8 V
#
# [966 rows x 11 columns]

# %% [markdown]
# That's a lot less rows. Oh dear. But what if we don't care about some of the columns with missing data?
#
# In your coursework you were asked to only look at the planet name, period, semi-major axis, detection technique and star mass columns. So let's create a new dataframe that only contains these columns. I'll call this one `planet_df`
#
# First we need to check the names of the columns we want, then we can make our new dataframe using these names:

# %%
exo_df.columns
# Out:
# Index(['name', 'orbital_period', 'semi_major_axis', 'eccentricity',
#        'discovered', 'detection_type', 'star_name', 'star_distance',
#        'star_metallicity', 'star_mass', 'star_sp_type'],
#       dtype='object')

# %%
planet_df = exo_df[['name', 'orbital_period', 'semi_major_axis', 'detection_type', 'star_mass']]

# %%
planet_df
# Out:
#                 name  orbital_period  semi_major_axis   detection_type  \
# 0           11 Com b      326.030000         1.290000  Radial Velocity
# 1           11 UMi b      516.220000         1.540000  Radial Velocity
# 2           14 And b      185.840000         0.830000  Radial Velocity
# 3           14 Her b     1773.400000         2.770000  Radial Velocity
# 4         16 Cyg B b      799.500000         1.680000  Radial Velocity
# 5           18 Del b      993.300000         2.600000  Radial Velocity
# 6     1SWASP J1407 b     3725.000000         3.900000  Primary Transit
# 7           24 Boo b       30.350600         0.190000  Radial Velocity
# 8           24 Sex b      452.800000         1.333000  Radial Velocity
# 9           24 Sex c      883.000000         2.080000  Radial Velocity
# 10        30 Ari B b      335.100000         0.995000  Radial Velocity
# 11          38 Vir b      825.900000         1.820000  Primary Transit
# 12           4 Uma b      269.300000         0.870000  Radial Velocity
# 13          42 Dra b      479.100000         1.190000  Radial Velocity
# 14          47 Uma b     1078.000000         2.100000  Radial Velocity
# 15          47 Uma c     2391.000000         3.600000  Radial Velocity
# 16          47 Uma d    14002.000000        11.600000  Radial Velocity
# 17          51 Peg b        4.230800         0.052000  Radial Velocity
# 18          55 Cnc b       14.653140         0.113390  Radial Velocity
# 19          55 Cnc c       44.373000         0.237350  Radial Velocity
# 20          55 Cnc d     4867.000000         5.446000  Radial Velocity
# 21          55 Cnc e        0.736548         0.015439  Primary Transit
# 22          55 Cnc f      260.910000         0.773300  Radial Velocity
# 23           6 Lyn b      899.000000         2.200000  Radial Velocity
# 24          61 Vir b        4.215000         0.050201  Radial Velocity
# 25          61 Vir c       38.021000         0.217500  Radial Velocity
# 26          61 Vir d      123.010000         0.476000  Radial Velocity
# 27           7 CMA c      988.900000         2.143000  Radial Velocity
# 28           7 CMa b      736.900000         1.761000  Radial Velocity
# 29          70 Vir b      116.670000         0.480000  Radial Velocity
# ...              ...             ...              ...              ...
# 3802   gamma 1 Leo b      428.500000         1.190000  Radial Velocity
# 3803  gamma Cephei b      903.300000         2.050000  Radial Velocity
# 3804     gamma Lib b      415.200000         1.239700  Radial Velocity
# 3805     gamma Lib c      964.600000         2.176100  Radial Velocity
# 3806     kappa CrB b     1251.000000         2.600000  Radial Velocity
# 3807     kepler-80 g       14.645580         0.140000  Primary Transit
# 3808       ksi Aql b      136.750000         0.580000  Radial Velocity
# 3809        mu Ara b      643.250000         1.500000  Radial Velocity
# 3810        mu Ara c        9.638600         0.090940  Radial Velocity
# 3811        mu Ara d      310.550000         0.921000  Radial Velocity
# 3812        mu Ara e     4205.800000         5.235000  Radial Velocity
# 3813        mu Leo b      357.800000         1.100000  Radial Velocity
# 3814        nu Oph b      530.210000         1.790000  Radial Velocity
# 3815        nu Oph c     3184.830000         5.931000  Radial Velocity
# 3816       ome Ser b      277.020000         1.100000  Radial Velocity
# 3817       omi CrB b      187.300000         0.830000  Radial Velocity
# 3818       omi UMa b     1630.000000         3.900000  Radial Velocity
# 3819        pi Men b     2091.200000         3.220000  Radial Velocity
# 3820        pi Men c        6.268340         0.067020  Primary Transit
# 3821       sig Per b      579.800000         1.800000  Radial Velocity
# 3822       tau Boo b        3.312490         0.046000  Radial Velocity
# 3823       tau Cet e      162.870000         0.538000  Radial Velocity
# 3824       tau Cet f      636.130000         1.334000  Radial Velocity
# 3825       tau Cet g       20.000000         0.133000  Radial Velocity
# 3826       tau Cet h       49.410000         0.243000  Radial Velocity
# 3827       tau Gem b      305.500000         1.170000  Radial Velocity
# 3828       ups And b        4.617110         0.059000  Radial Velocity
# 3829       ups And c      240.937000         0.861000  Radial Velocity
# 3830       ups And d     1281.439000         2.550000  Radial Velocity
# 3831       ups And e     3848.860000         5.245600  Radial Velocity
#
#       star_mass
# 0         2.700
# 1         1.800
# 2         2.200
# 3         0.900
# 4         1.010
# 5         2.300
# 6         0.900
# 7         0.990
# 8         1.540
# 9         1.540
# 10        1.220
# 11        1.180
# 12        1.234
# 13        0.980
# 14        1.030
# 15        1.030
# 16        1.030
# 17        1.110
# 18        1.015
# 19        1.015
# 20        1.015
# 21        1.015
# 22        1.015
# 23        1.700
# 24        0.950
# 25        0.950
# 26        0.950
# 27        1.520
# 28        1.520
# 29        0.920
# ...         ...
# 3802      1.230
# 3803      1.400
# 3804      1.470
# 3805      1.470
# 3806      1.510
# 3807        NaN
# 3808      2.200
# 3809      1.080
# 3810      1.080
# 3811      1.080
# 3812      1.080
# 3813      1.500
# 3814      3.040
# 3815      3.040
# 3816      2.170
# 3817      2.130
# 3818      3.090
# 3819      1.094
# 3820      1.094
# 3821      2.250
# 3822      1.300
# 3823      0.783
# 3824      0.783
# 3825      0.783
# 3826      0.783
# 3827      2.300
# 3828      1.270
# 3829      1.270
# 3830      1.270
# 3831      1.270
#
# [3832 rows x 5 columns]

# %% [markdown]
# Now we can check how many of these rows and columns contain `NaN` values. Rather than print out the dataframe and read the number underneath, we can use the `shape` attribute.

# %%
planet_df[planet_df.isna().any(axis=1)].shape
# Out:
# (1783, 5)

# %% [markdown]
# This dataframe has fewer rows with missing data than the first, but still has a lot. We only care about the rows that don't have any missing data. We could use the same operation as we did before to return only the complete rows, but an easier way to do it is to use `dropna`. This removes any rows with missing data. If we'd done this on the original dataframe we'd have lost a lot of rows that are perfectly fine for our analysis but have missing data in another column. By using our new dataframe we don't remove data unnecessarily. Setting `inplace=True` tells Python to edit the dataframe rather than just show us the results.

# %%
planet_df.dropna(inplace=True)
# Out:
# /Users/vs522/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Information: `SettingWithCopyWarning`
# You may have got a warning when you ran the `dropna(inplace=True)` command. First - don't panic! This is a warning, not an error. Here the warning is telling us that we're editing a copy of part of another dataframe, not the original dataframe. That's exactly what we intended here so it's not a problem. It becomes more important when you're doing more complex data analysis (more complex that we'll reach in this course), but for now we just need to understand what it's telling us and move on.

# %% [markdown]
# Let's take another look at our `planet_df` dataframe:

# %%
planet_df
# Out:
#                 name  orbital_period  semi_major_axis   detection_type  \
# 0           11 Com b      326.030000         1.290000  Radial Velocity
# 1           11 UMi b      516.220000         1.540000  Radial Velocity
# 2           14 And b      185.840000         0.830000  Radial Velocity
# 3           14 Her b     1773.400000         2.770000  Radial Velocity
# 4         16 Cyg B b      799.500000         1.680000  Radial Velocity
# 5           18 Del b      993.300000         2.600000  Radial Velocity
# 6     1SWASP J1407 b     3725.000000         3.900000  Primary Transit
# 7           24 Boo b       30.350600         0.190000  Radial Velocity
# 8           24 Sex b      452.800000         1.333000  Radial Velocity
# 9           24 Sex c      883.000000         2.080000  Radial Velocity
# 10        30 Ari B b      335.100000         0.995000  Radial Velocity
# 11          38 Vir b      825.900000         1.820000  Primary Transit
# 12           4 Uma b      269.300000         0.870000  Radial Velocity
# 13          42 Dra b      479.100000         1.190000  Radial Velocity
# 14          47 Uma b     1078.000000         2.100000  Radial Velocity
# 15          47 Uma c     2391.000000         3.600000  Radial Velocity
# 16          47 Uma d    14002.000000        11.600000  Radial Velocity
# 17          51 Peg b        4.230800         0.052000  Radial Velocity
# 18          55 Cnc b       14.653140         0.113390  Radial Velocity
# 19          55 Cnc c       44.373000         0.237350  Radial Velocity
# 20          55 Cnc d     4867.000000         5.446000  Radial Velocity
# 21          55 Cnc e        0.736548         0.015439  Primary Transit
# 22          55 Cnc f      260.910000         0.773300  Radial Velocity
# 23           6 Lyn b      899.000000         2.200000  Radial Velocity
# 24          61 Vir b        4.215000         0.050201  Radial Velocity
# 25          61 Vir c       38.021000         0.217500  Radial Velocity
# 26          61 Vir d      123.010000         0.476000  Radial Velocity
# 27           7 CMA c      988.900000         2.143000  Radial Velocity
# 28           7 CMa b      736.900000         1.761000  Radial Velocity
# 29          70 Vir b      116.670000         0.480000  Radial Velocity
# ...              ...             ...              ...              ...
# 3801       eta Cet c      751.900000         1.930000  Radial Velocity
# 3802   gamma 1 Leo b      428.500000         1.190000  Radial Velocity
# 3803  gamma Cephei b      903.300000         2.050000  Radial Velocity
# 3804     gamma Lib b      415.200000         1.239700  Radial Velocity
# 3805     gamma Lib c      964.600000         2.176100  Radial Velocity
# 3806     kappa CrB b     1251.000000         2.600000  Radial Velocity
# 3808       ksi Aql b      136.750000         0.580000  Radial Velocity
# 3809        mu Ara b      643.250000         1.500000  Radial Velocity
# 3810        mu Ara c        9.638600         0.090940  Radial Velocity
# 3811        mu Ara d      310.550000         0.921000  Radial Velocity
# 3812        mu Ara e     4205.800000         5.235000  Radial Velocity
# 3813        mu Leo b      357.800000         1.100000  Radial Velocity
# 3814        nu Oph b      530.210000         1.790000  Radial Velocity
# 3815        nu Oph c     3184.830000         5.931000  Radial Velocity
# 3816       ome Ser b      277.020000         1.100000  Radial Velocity
# 3817       omi CrB b      187.300000         0.830000  Radial Velocity
# 3818       omi UMa b     1630.000000         3.900000  Radial Velocity
# 3819        pi Men b     2091.200000         3.220000  Radial Velocity
# 3820        pi Men c        6.268340         0.067020  Primary Transit
# 3821       sig Per b      579.800000         1.800000  Radial Velocity
# 3822       tau Boo b        3.312490         0.046000  Radial Velocity
# 3823       tau Cet e      162.870000         0.538000  Radial Velocity
# 3824       tau Cet f      636.130000         1.334000  Radial Velocity
# 3825       tau Cet g       20.000000         0.133000  Radial Velocity
# 3826       tau Cet h       49.410000         0.243000  Radial Velocity
# 3827       tau Gem b      305.500000         1.170000  Radial Velocity
# 3828       ups And b        4.617110         0.059000  Radial Velocity
# 3829       ups And c      240.937000         0.861000  Radial Velocity
# 3830       ups And d     1281.439000         2.550000  Radial Velocity
# 3831       ups And e     3848.860000         5.245600  Radial Velocity
#
#       star_mass
# 0         2.700
# 1         1.800
# 2         2.200
# 3         0.900
# 4         1.010
# 5         2.300
# 6         0.900
# 7         0.990
# 8         1.540
# 9         1.540
# 10        1.220
# 11        1.180
# 12        1.234
# 13        0.980
# 14        1.030
# 15        1.030
# 16        1.030
# 17        1.110
# 18        1.015
# 19        1.015
# 20        1.015
# 21        1.015
# 22        1.015
# 23        1.700
# 24        0.950
# 25        0.950
# 26        0.950
# 27        1.520
# 28        1.520
# 29        0.920
# ...         ...
# 3801      1.700
# 3802      1.230
# 3803      1.400
# 3804      1.470
# 3805      1.470
# 3806      1.510
# 3808      2.200
# 3809      1.080
# 3810      1.080
# 3811      1.080
# 3812      1.080
# 3813      1.500
# 3814      3.040
# 3815      3.040
# 3816      2.170
# 3817      2.130
# 3818      3.090
# 3819      1.094
# 3820      1.094
# 3821      2.250
# 3822      1.300
# 3823      0.783
# 3824      0.783
# 3825      0.783
# 3826      0.783
# 3827      2.300
# 3828      1.270
# 3829      1.270
# 3830      1.270
# 3831      1.270
#
# [2049 rows x 5 columns]

# %% [markdown]
# It definately has fewer rows than before, but we should still check that they're all complete...

# %% [markdown]
# ## Exercise: Check your data
#
# Use the `isna` function to check that you have properly cleaned the `planet_df` dataframe. Check the shape of the dataframe returned when you use `isna` and its inverse.
#
# [solution]()

# %% [markdown]
# ## Solution+: Check your data

# %%
planet_df[planet_df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [name, orbital_period, semi_major_axis, detection_type, star_mass]
# Index: []

# %%
planet_df[planet_df.isna().any(axis=1)].shape
# Out:
# (0, 5)

# %%
planet_df[~planet_df.isna().any(axis=1)]
# Out:
#                 name  orbital_period  semi_major_axis   detection_type  \
# 0           11 Com b      326.030000         1.290000  Radial Velocity
# 1           11 UMi b      516.220000         1.540000  Radial Velocity
# 2           14 And b      185.840000         0.830000  Radial Velocity
# 3           14 Her b     1773.400000         2.770000  Radial Velocity
# 4         16 Cyg B b      799.500000         1.680000  Radial Velocity
# 5           18 Del b      993.300000         2.600000  Radial Velocity
# 6     1SWASP J1407 b     3725.000000         3.900000  Primary Transit
# 7           24 Boo b       30.350600         0.190000  Radial Velocity
# 8           24 Sex b      452.800000         1.333000  Radial Velocity
# 9           24 Sex c      883.000000         2.080000  Radial Velocity
# 10        30 Ari B b      335.100000         0.995000  Radial Velocity
# 11          38 Vir b      825.900000         1.820000  Primary Transit
# 12           4 Uma b      269.300000         0.870000  Radial Velocity
# 13          42 Dra b      479.100000         1.190000  Radial Velocity
# 14          47 Uma b     1078.000000         2.100000  Radial Velocity
# 15          47 Uma c     2391.000000         3.600000  Radial Velocity
# 16          47 Uma d    14002.000000        11.600000  Radial Velocity
# 17          51 Peg b        4.230800         0.052000  Radial Velocity
# 18          55 Cnc b       14.653140         0.113390  Radial Velocity
# 19          55 Cnc c       44.373000         0.237350  Radial Velocity
# 20          55 Cnc d     4867.000000         5.446000  Radial Velocity
# 21          55 Cnc e        0.736548         0.015439  Primary Transit
# 22          55 Cnc f      260.910000         0.773300  Radial Velocity
# 23           6 Lyn b      899.000000         2.200000  Radial Velocity
# 24          61 Vir b        4.215000         0.050201  Radial Velocity
# 25          61 Vir c       38.021000         0.217500  Radial Velocity
# 26          61 Vir d      123.010000         0.476000  Radial Velocity
# 27           7 CMA c      988.900000         2.143000  Radial Velocity
# 28           7 CMa b      736.900000         1.761000  Radial Velocity
# 29          70 Vir b      116.670000         0.480000  Radial Velocity
# ...              ...             ...              ...              ...
# 3801       eta Cet c      751.900000         1.930000  Radial Velocity
# 3802   gamma 1 Leo b      428.500000         1.190000  Radial Velocity
# 3803  gamma Cephei b      903.300000         2.050000  Radial Velocity
# 3804     gamma Lib b      415.200000         1.239700  Radial Velocity
# 3805     gamma Lib c      964.600000         2.176100  Radial Velocity
# 3806     kappa CrB b     1251.000000         2.600000  Radial Velocity
# 3808       ksi Aql b      136.750000         0.580000  Radial Velocity
# 3809        mu Ara b      643.250000         1.500000  Radial Velocity
# 3810        mu Ara c        9.638600         0.090940  Radial Velocity
# 3811        mu Ara d      310.550000         0.921000  Radial Velocity
# 3812        mu Ara e     4205.800000         5.235000  Radial Velocity
# 3813        mu Leo b      357.800000         1.100000  Radial Velocity
# 3814        nu Oph b      530.210000         1.790000  Radial Velocity
# 3815        nu Oph c     3184.830000         5.931000  Radial Velocity
# 3816       ome Ser b      277.020000         1.100000  Radial Velocity
# 3817       omi CrB b      187.300000         0.830000  Radial Velocity
# 3818       omi UMa b     1630.000000         3.900000  Radial Velocity
# 3819        pi Men b     2091.200000         3.220000  Radial Velocity
# 3820        pi Men c        6.268340         0.067020  Primary Transit
# 3821       sig Per b      579.800000         1.800000  Radial Velocity
# 3822       tau Boo b        3.312490         0.046000  Radial Velocity
# 3823       tau Cet e      162.870000         0.538000  Radial Velocity
# 3824       tau Cet f      636.130000         1.334000  Radial Velocity
# 3825       tau Cet g       20.000000         0.133000  Radial Velocity
# 3826       tau Cet h       49.410000         0.243000  Radial Velocity
# 3827       tau Gem b      305.500000         1.170000  Radial Velocity
# 3828       ups And b        4.617110         0.059000  Radial Velocity
# 3829       ups And c      240.937000         0.861000  Radial Velocity
# 3830       ups And d     1281.439000         2.550000  Radial Velocity
# 3831       ups And e     3848.860000         5.245600  Radial Velocity
#
#       star_mass
# 0         2.700
# 1         1.800
# 2         2.200
# 3         0.900
# 4         1.010
# 5         2.300
# 6         0.900
# 7         0.990
# 8         1.540
# 9         1.540
# 10        1.220
# 11        1.180
# 12        1.234
# 13        0.980
# 14        1.030
# 15        1.030
# 16        1.030
# 17        1.110
# 18        1.015
# 19        1.015
# 20        1.015
# 21        1.015
# 22        1.015
# 23        1.700
# 24        0.950
# 25        0.950
# 26        0.950
# 27        1.520
# 28        1.520
# 29        0.920
# ...         ...
# 3801      1.700
# 3802      1.230
# 3803      1.400
# 3804      1.470
# 3805      1.470
# 3806      1.510
# 3808      2.200
# 3809      1.080
# 3810      1.080
# 3811      1.080
# 3812      1.080
# 3813      1.500
# 3814      3.040
# 3815      3.040
# 3816      2.170
# 3817      2.130
# 3818      3.090
# 3819      1.094
# 3820      1.094
# 3821      2.250
# 3822      1.300
# 3823      0.783
# 3824      0.783
# 3825      0.783
# 3826      0.783
# 3827      2.300
# 3828      1.270
# 3829      1.270
# 3830      1.270
# 3831      1.270
#
# [2049 rows x 5 columns]

# %%
planet_df[~planet_df.isna().any(axis=1)].shape
# Out:
# (2049, 5)

# %% [markdown]
# :solution+

# %% [markdown]
# ## Key Points:
# - Missing data is represented as `NaN` or 'Not a Number'
# - You can use the `na_values` argument of `pd.read_csv` to tell `pandas` which values correspond to missing data.
# - `isna()` can be used to find missing data
# - You can use `~` to return the inverse of a logical expression.
